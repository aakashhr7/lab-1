# %%
print("hello world")
# Out:
# hello world

# %%
name= "Aakash Rana"
print("Name:",name)
age= 23
print("Age:",age)
height=1.85
print("Height:",height,"metres")

print(type(name))
print(type(age))
print(type(height))
# Out:
# Name: Aakash Rana
# Age: 23
# Height: 1.85 metres
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
name=input("Name:")
age=int(input("Age:"))
height=float(input("Height(in mtr):"))
print("Hii",name,",your age is",age,"and height is",height,"metres." )
# Out:
# Name: Aakash Rana
# Age: 23
# Height(in mtr): 1.85
# Hii Aakash Rana ,your age is 23 and height is 1.85 metres.

# %%
length=float(input("Length of Rectangle:"))
width=float(input("Width of Rectangle:"))
print("Area of Rectangle is",length*width,"units")
print("Perimeter of Rectangle is",length+width,"units")
# Out:
# Length of Rectangle: 45
# Width of Rectangle: 87
# Area of Rectangle is 3915.0 units
# Perimeter of Rectangle is 132.0 units

# %%
weight=float(input("Your Weight in kg:"))
height=float(input("Your Height in metres:"))
print("Your BMI is",weight/(height**2))
# Out:
# Your Weight in kg: 68
# Your Height in metres: 1.85
# Your BMI is 19.86851716581446
